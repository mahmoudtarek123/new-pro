# %%
import requests
from bs4 import BeautifulSoup
import csv

# %%
x=requests.get("https://www.youtube.com/feed/channels")
asd=x.content
print(asd)
# Out:
# b'\n<!DOCTYPE html>\n<html lang="ar">\n  <head>\n  <meta charset="utf-8">\n  <meta content="width=300, initial-scale=1" name="viewport">\n  <meta name="description" content="\xd9\x85\xd8\xb4\xd8\xa7\xd8\xb1\xd9\x83\xd8\xa9 \xd8\xa7\xd9\x84\xd9\x81\xd9\x8a\xd8\xaf\xd9\x8a\xd9\x88\xd9\x87\xd8\xa7\xd8\xaa \xd9\x85\xd8\xb9 \xd8\xa7\xd9\x84\xd8\xa3\xd8\xb5\xd8\xaf\xd9\x82\xd8\xa7\xd8\xa1 \xd9\x88\xd8\xa7\xd9\x84\xd8\xb9\xd8\xa7\xd8\xa6\xd9\x84\xd8\xa9 \xd9\x88\xd8\xa7\xd9\x84\xd8\xa2\xd8\xae\xd8\xb1\xd9\x8a\xd9\x86 \xd8\xb9\xd8\xa8\xd8\xb1 \xd8\xa7\xd9\x84\xd8\xb9\xd8\xa7\xd9\x84\xd9\x85.">\n  <meta name="google-site-verification" content="LrdTUW9psUAMbh4Ia074-BPEVmcpBxF6Gwf0MSgQXZs">\n  <title>YouTube</title>\n<style>\n  html, body {\n  font-family: Arial, sans-serif;\n  background: #fff;\n  margin: 0;\n  padding: 0;\n  border: 0;\n  position: absolute;\n  height: 100%;\n  min-width: 100%;\n  font-size: 13px;\n  color: #404040;\n  direction: rtl;\n  -webkit-text-size-adjust: none;\n  }\n
# ...

# %%
soup
# Out:
# 'lxml'

# %%
print(soup)
# Out:
# lxml

# %%
print(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19264/1956260530.py in <module>
# ----> 1 print(soup.prettify())
#
# AttributeError: 'str' object has no attribute 'prettify'

# %%
match=soup.find_altitle.text)
print(match)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19264/1744404479.py in <module>
# ----> 1 match=soup.find_all(title.text)
#       2 print(match)
#
# AttributeError: 'str' object has no attribute 'find_all'
